# %%
#Clone YOLOv5 and install requirements
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17485, done.
# remote: Counting objects: 100% (109/109), done.
# remote: Compressing objects: 100% (79/79), done.
# remote: Total 17485 (delta 79), reused 30 (delta 30), pack-reused 17376 (from 4)
# Receiving objects: 100% (17485/17485), 16.39 MiB | 29.08 MiB/s, done.
# Resolving deltas: 100% (11984/11984), done.
# /content/yolov5/yolov5
# ...

# %%
#Install requirements
# %pip install -r requirements.txt
# !pip install roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 68.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 37.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 53.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 828.3 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 100.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 69.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
#Download dataset from Roboflow
from roboflow import Roboflow
rf = Roboflow(api_key="hAgbJLrdz68ykSA7j1oc")
project = rf.workspace("abdelaadimkhriss").project("ocean-plastics-waste-detection-float-plastics")
version = project.version(13)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Ocean-Plastics-Waste-Detection---Float-Plastics-13 in yolov5pytorch:: 100%|██████████| 9990/9990 [00:01<00:00, 7803.32it/s]

# %%
# Train YOLOv5n on the Roboflow dataset
# !python train.py \
  --img 640 \
  --batch 16 \
  --epochs 50 \
  --data Ocean-Plastics-Waste-Detection---Float-Plastics-13/data.yaml \
  --cfg models/yolov5n.yaml \
  --weights yolov5n.pt \
  --name garbage_yolov5n
# Out:
# Streaming output truncated to the last 5000 lines.
#   with torch.cuda.amp.autocast(amp):
#       41/49      2.57G    0.03297    0.02295   0.007626         30        640:  10% 27/275 [00:10<02:22,  1.75it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       41/49      2.57G    0.03282    0.02264   0.007555         42        640:  10% 28/275 [00:10<01:56,  2.13it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       41/49      2.57G    0.03282    0.02268   0.007526         58        640:  11% 29/275 [00:11<02:13,  1.85it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
# ...

# %%
#Download the model
from google.colab import files
files.download('runs/train/garbage_yolov5n/weights/best.pt')

# %%
#Upload to google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp runs/train/garbage_yolov5n/weights/best.pt /content/drive/MyDrive/
# Out:
# cp: cannot stat 'runs/train/garbage_yolov5n/weights/best.pt': No such file or directory
